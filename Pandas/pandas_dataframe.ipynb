# %% [markdown]
# Data frame is used to read tabular data

# %%
# columns - features

# %%
import numpy as np
import pandas as np

# %%
import pandas as pd

# Creating dataframe
# using lists
data_sample = [
    [50,60,47],
    [70,73,75],
    [10,400,3],
    [60,5,20]
]
data1 = pd.DataFrame(data_sample,columns = ['python','C++','Java'])
data1
# Out:
#    python  C++  Java
# 0      50   60    47
# 1      70   73    75
# 2      10  400     3
# 3      60    5    20

# %%
data_dict = {
    'col1' : ['name1','name2','name3','name4','name5','name6'],
    'col2' : [100,90,80,0,0,0],
    'col3' : [88,70,100,50,0,0],
    'col4' : [10,7,14,2,0,0]
}
students = pd.DataFrame(data_dict)
students
students.set_index('col1', inplace=True)
#"in-place" refers to operations that modify an object
#  directly without creating a new object. This contrasts 
# with operations that return a new modified object while
#  leaving the original object unchanged
students
# Out:
#        col2  col3  col4
# col1
# name1   100    88    10
# name2    90    70     7
# name3    80   100    14
# name4     0    50     2
# name5     0     0     0
# name6     0     0     0

# %%
# using read_csv
titanic = pd.read_csv("Titanic Dataset.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
weather = pd.read_csv("austin_weather.csv")
weather
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0     2013-12-21         74        60        45            67           49
# 1     2013-12-22         56        48        39            43           36
# 2     2013-12-23         58        45        32            31           27
# 3     2013-12-24         61        46        31            36           28
# 4     2013-12-25         58        50        41            44           40
# ...          ...        ...       ...       ...           ...          ...
# 1314  2017-07-27        103        89        75            71           67
# 1315  2017-07-28        105        91        76            71           64
# 1316  2017-07-29        107        92        77            72           64
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
# ...

# %%
weather.columns
# Out:
# Index(['Date', 'TempHighF', 'TempAvgF', 'TempLowF', 'DewPointHighF',
#        'DewPointAvgF', 'DewPointLowF', 'HumidityHighPercent',
#        'HumidityAvgPercent', 'HumidityLowPercent',
#        'SeaLevelPressureHighInches', 'SeaLevelPressureAvgInches',
#        'SeaLevelPressureLowInches', 'VisibilityHighMiles',
#        'VisibilityAvgMiles', 'VisibilityLowMiles', 'WindHighMPH', 'WindAvgMPH',
#        'WindGustMPH', 'PrecipitationSumInches', 'Events'],
#       dtype='object')

# %%
# shape
print(titanic.shape)
print(weather.shape)
# Out:
# (418, 12)
# (1319, 21)

# %%
# dtype
print(titanic.dtypes)
print()
print(weather.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
#
# Date                          object
# TempHighF                      int64
# TempAvgF                       int64
# TempLowF                       int64
# DewPointHighF                 object
# DewPointAvgF                  object
# DewPointLowF                  object
# HumidityHighPercent           object
# HumidityAvgPercent            object
# HumidityLowPercent            object
# SeaLevelPressureHighInches    object
# SeaLevelPressureAvgInches     object
# SeaLevelPressureLowInches     object
# VisibilityHighMiles           object
# VisibilityAvgMiles            object
# VisibilityLowMiles            object
# WindHighMPH                   object
# ...

# %%
# index
print(students.index)
print(titanic.index)
print(weather.index)
# Out:
# Index(['name1', 'name2', 'name3', 'name4', 'name5', 'name6'], dtype='object', name='col1')
# RangeIndex(start=0, stop=418, step=1)
# RangeIndex(start=0, stop=1319, step=1)

# %%
# columns
print(titanic.columns)
print(weather.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# Index(['Date', 'TempHighF', 'TempAvgF', 'TempLowF', 'DewPointHighF',
#        'DewPointAvgF', 'DewPointLowF', 'HumidityHighPercent',
#        'HumidityAvgPercent', 'HumidityLowPercent',
#        'SeaLevelPressureHighInches', 'SeaLevelPressureAvgInches',
#        'SeaLevelPressureLowInches', 'VisibilityHighMiles',
#        'VisibilityAvgMiles', 'VisibilityLowMiles', 'WindHighMPH', 'WindAvgMPH',
#        'WindGustMPH', 'PrecipitationSumInches', 'Events'],
#       dtype='object')

# %%
# values
print(titanic.values)
# Out:
# [[892 0 3 ... 7.8292 nan 'Q']
#  [893 1 3 ... 7.0 nan 'S']
#  [894 0 2 ... 9.6875 nan 'Q']
#  ...
#  [1307 0 3 ... 7.25 nan 'S']
#  [1308 0 3 ... 8.05 nan 'S']
#  [1309 0 3 ... 22.3583 nan 'C']]

# %%
# head
# print top five rows by default
titanic.head()
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S

# %%
# tail
# print last five rows by default
weather.tail()
weather.tail(2)
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
#      DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# 1317           63                  69                 48                 27
# 1318           54                  64                 43                 22
#
#       ... SeaLevelPressureAvgInches SeaLevelPressureLowInches  \
# 1317  ...                     29.91                     29.87
# 1318  ...                     29.97                     29.91
#
#      VisibilityHighMiles VisibilityAvgMiles VisibilityLowMiles WindHighMPH  \
# 1317                  10                 10                 10          13
# 1318                  10                 10                 10          12
#
#      WindAvgMPH WindGustMPH PrecipitationSumInches Events
# ...

# %%
# sample
# print random 1 row
# for in balance dataset
titanic.sample()
# Out:
#     PassengerId  Survived  Pclass                             Name   Sex  \
# 73          965         0       1  Ovies y Rodriguez, Mr. Servando  male
#
#      Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 73  28.5      0      0  PC 17562  27.7208   D43        C

# %%
# info
# information about memory and other things
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        1319 non-null   object
#  1   TempHighF                   1319 non-null   int64
#  2   TempAvgF                    1319 non-null   int64
#  3   TempLowF                    1319 non-null   int64
#  4   DewPointHighF               1319 non-null   object
#  5   DewPointAvgF                1319 non-null   object
#  6   DewPointLowF                1319 non-null   object
#  7   HumidityHighPercent         1319 non-null   object
#  8   HumidityAvgPercent          1319 non-null   object
#  9   HumidityLowPercent          1319 non-null   object
#  10  SeaLevelPressureHighInches  1319 non-null   object
#  11  SeaLevelPressureAvgInches   1319 non-null   object
#  12  SeaLevelPressureLowInches   1319 non-null   object
# ...

# %%
# describe
# describe the mathamatical values
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
weather.describe()
# Out:
#          TempHighF     TempAvgF     TempLowF
# count  1319.000000  1319.000000  1319.000000
# mean     80.862775    70.642911    59.902957
# std      14.766523    14.045904    14.190648
# min      32.000000    29.000000    19.000000
# 25%      72.000000    62.000000    49.000000
# 50%      83.000000    73.000000    63.000000
# 75%      92.000000    83.000000    73.000000
# max     107.000000    93.000000    81.000000

# %%
# is null
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# duplicate
titanic.duplicated().sum()
# Out:
# np.int64(0)

# %%
x=students.rename(columns={'col1':'python','col2':'c++'},inplace=True)
print(x)
# Out:
# None

# %%
# sum -> axis argument
# pandas row 1
students.sum(axis=0)
# Out:
# c++     270
# col3    308
# col4     33
# dtype: int64

# %%
students.sum(axis=1)
# Out:
# col1
# name1    198
# name2    167
# name3    194
# name4     52
# name5      0
# name6      0
# dtype: int64

# %%
# mean
students.mean(axis=1)
# Out:
# col1
# name1    66.000000
# name2    55.666667
# name3    64.666667
# name4    17.333333
# name5     0.000000
# name6     0.000000
# dtype: float64

# %%
# varience
students.var()
# Out:
# c++     2470.000000
# col3    1866.666667
# col4      33.500000
# dtype: float64

# %%
# satndard deviation
students.std()
# Out:
# c++     49.699095
# col3    43.204938
# col4     5.787918
# dtype: float64

# %%
# single column
titanic[['Name']]
# Out:
#                                              Name
# 0                                Kelly, Mr. James
# 1                Wilkes, Mrs. James (Ellen Needs)
# 2                       Myles, Mr. Thomas Francis
# 3                                Wirz, Mr. Albert
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..                                            ...
# 413                            Spector, Mr. Woolf
# 414                  Oliva y Ocana, Dona. Fermina
# 415                  Saether, Mr. Simon Sivertsen
# 416                           Ware, Mr. Frederick
# 417                      Peter, Master. Michael J
#
# [418 rows x 1 columns]

# %%
weather[['Date', 'TempAvgF', 'Events']]
# Out:
#             Date  TempAvgF               Events
# 0     2013-12-21        60  Rain , Thunderstorm
# 1     2013-12-22        48
# 2     2013-12-23        45
# 3     2013-12-24        46
# 4     2013-12-25        50
# ...          ...       ...                  ...
# 1314  2017-07-27        89
# 1315  2017-07-28        91
# 1316  2017-07-29        92
# 1317  2017-07-30        93
# 1318  2017-07-31        88
#
# [1319 rows x 3 columns]

# %%
titanic[['PassengerId', 'Survived', 'Pclass']]
# Out:
#      PassengerId  Survived  Pclass
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
# [418 rows x 3 columns]

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# accessing single row
titanic.iloc[5]
# Out:
# PassengerId                           897
# Survived                                0
# Pclass                                  3
# Name           Svensson, Mr. Johan Cervin
# Sex                                  male
# Age                                  14.0
# SibSp                                   0
# Parch                                   0
# Ticket                               7538
# Fare                                9.225
# Cabin                                 NaN
# Embarked                                S
# Name: 5, dtype: object

# %%
# accessing multiple rows together
titanic.iloc[:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# fancy indexing -> giving index value returns that row
titanic.iloc[0,4]
# Out:
# 'male'

# %%
students.loc['name1']
# Out:
# c++     100
# col3     88
# col4     10
# Name: name1, dtype: int64

# %%
students.loc['name1':'name5':2]
# Out:
#        c++  col3  col4
# col1
# name1  100    88    10
# name3   80   100    14
# name5    0     0     0

# %%
# rows and columns
titanic.iloc[0:3,0:7]
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
#
#     Age  SibSp
# 0  34.5      0
# 1  47.0      1
# 2  62.0      0

# %%
# completely new
titanic['country'] = 'India'
titanic.sample(10)
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 264         1156         0       2  Portaluppi, Mr. Emilio Ilario Giuseppe
# 16           908         0       2                       Keane, Mr. Daniel
# 29           921         0       3                       Samaan, Mr. Elias
# 345         1237         1       3             Abelseth, Miss. Karen Marie
# 267         1159         0       3             Warren, Mr. Charles William
# 336         1228         0       2              de Brito, Mr. Jose Joaquim
# 114         1006         1       1  Straus, Mrs. Isidor (Rosalie Ida Blun)
# 147         1039         0       3                        Davies, Mr. Evan
# 91           983         0       3                      Pedersen, Mr. Olaf
# 260         1152         0       3    de Messemaeker, Mr. Guillaume Joseph
#
#         Sex   Age  SibSp  Parch       Ticket      Fare    Cabin Embarked  \
# ...

# %%
titanic['First name'] = titanic['Name'].str.split(',').apply(lambda x:x[0])
titanic['First name']
# Out:
# 0              Kelly
# 1             Wilkes
# 2              Myles
# 3               Wirz
# 4           Hirvonen
#            ...
# 413          Spector
# 414    Oliva y Ocana
# 415          Saether
# 416             Ware
# 417            Peter
# Name: First name, Length: 418, dtype: object

# %%
#wap to take a string input from user and print its first name
def print_first_name():
 
  full_name = input()
  first_name = full_name.split()[0]
  print(first_name)

print_first_name()
# Out:
# Siddharth

# %%
x = ["How",'are','you']
y = " ".join(x)
print(y)
# Out:
# How are you

# %%
name = input("Enter your name")
print(" ".join(name.split()[:-1]))
# Out:
# Siddharth

# %%
titanic['PassengerId'] = titanic['PassengerId'].astype('int32')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int32
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
#  12  country      418 non-null    object
#  13  First name   418 non-null    object
# dtypes: float64(2), int32(1), int64(4), object(7)
# memory usage: 44.2+ KB

# %%
# value count
students.value_counts()
# counting no. of rows have same values in all attributes
# Out:
# c++  col3  col4
# 0    0     0       2
#      50    2       1
# 80   100   14      1
# 90   70    7       1
# 100  88    10      1
# Name: count, dtype: int64

# %%
titanic['Pclass'].unique
# Out:
# <bound method Series.unique of 0      3
# 1      3
# 2      2
# 3      3
# 4      3
#       ..
# 413    3
# 414    1
# 415    3
# 416    3
# 417    3
# Name: Pclass, Length: 418, dtype: int64>

# %%
# find how many passengers are their in each class?
titanic['Pclass'].value_counts()
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
# find the counts values in events in weather
weather['Events'].value_counts()
# Out:
# Events
#                              903
# Rain                         192
# Rain , Thunderstorm          137
# Fog , Rain , Thunderstorm     33
# Fog                           21
# Thunderstorm                  17
# Fog , Rain                    14
# Rain , Snow                    1
# Fog , Thunderstorm             1
# Name: count, dtype: int64

# %%
# count no. of passengers which are male and age is above 40
((titanic['Age']>=40)&(titanic['Sex']=='male')).value_counts()
# Out:
# False    366
# True      52
# Name: count, dtype: int64

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# counts of passengers which when solo on titatic
((titanic['SibSp']==0)&(titanic['Parch']==0)).value_counts()
# Out:
# True     253
# False    165
# Name: count, dtype: int64

# %%
(((titanic['Age']>50)&(titanic['Sex']=='male')) | ((titanic['Age']>40)&(titanic['Sex']=='female'))).value_counts()
# Out:
# False    372
# True      46
# Name: count, dtype: int64

# %% [markdown]
# sort_values()

# %%
titanic.sort_values('PassengerId',ascending = False)
# Out:
#      PassengerId  Survived  Pclass  \
# 417         1309         0       3
# 416         1308         0       3
# 415         1307         0       3
# 414         1306         1       1
# 413         1305         0       3
# ..           ...       ...     ...
# 4            896         1       3
# 3            895         0       3
# 2            894         0       2
# 1            893         1       3
# 0            892         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 417                      Peter, Master. Michael J    male   NaN      1      1
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# ...

# %%
# more than one columns
titanic.sort_values(['Pclass','Name'],ascending = [True,False])
# workng ???
# Out:
#      PassengerId  Survived  Pclass  \
# 371         1263         1       1
# 23           915         0       1
# 231         1123         1       1
# 218         1110         1       1
# 407         1299         0       1
# ..           ...       ...     ...
# 8            900         1       3
# 251         1143         0       3
# 57           949         0       3
# 345         1237         1       3
# 392         1284         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 371                     Wilson, Miss. Helen Alice  female  31.0      0      0
# 23                Williams, Mr. Richard Norris II    male  21.0      0      1
# 231                      Willard, Miss. Constance  female  21.0      0      0
# 218  Widener, Mrs. George Dunton (Eleanor Elkins)  female  50.0      1      1
# 407                    Widener, Mr. George Dunton    male  50.0      1      1
# ...

# %% [markdown]
# set_index(),reset_index()

# %%
titanic.sample(10)
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 129         1021         0       3            Petersen, Mr. Marius    male
# 417         1309         0       3        Peter, Master. Michael J    male
# 396         1288         0       3            Colbert, Mr. Patrick    male
# 6            898         1       3            Connolly, Miss. Kate  female
# 340         1232         0       2   Fillbrook, Mr. Joseph Charles    male
# 88           980         1       3         O'Donoghue, Ms. Bridget  female
# 270         1162         0       1    McCaffry, Mr. Thomas Francis    male
# 9            901         0       3         Davies, Mr. John Samuel    male
# 78           970         0       2  Aldworth, Mr. Charles Augustus    male
# 105          997         0       3       Holthen, Mr. Johan Martin    male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked country  \
# 129  24.0      0      0      342441   8.0500   NaN        S   India
# ...

# %%
# titanic.set_index('PassengerId',inplace = True)

# %%
# Converting series into dataframe using reset_index()
marks = {
    'maths':67,
    'maths':57,
    'maths':89,
    'maths':100,
}

marks_series = pd.Series(marks)
marks_series
# Out:
# maths    100
# dtype: int64

# %%
titanic['Pclass'].unique
# Out:
# <bound method Series.unique of PassengerId
# 892     3
# 893     3
# 894     2
# 895     3
# 896     3
#        ..
# 1305    3
# 1306    1
# 1307    3
# 1308    3
# 1309    3
# Name: Pclass, Length: 418, dtype: int64>

# %%
titanic['Pclass'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of PassengerId
# 892     3
# 893     3
# 894     2
# 895     3
# 896     3
#        ..
# 1305    3
# 1306    1
# 1307    3
# 1308    3
# 1309    3
# Name: Pclass, Length: 418, dtype: int64>

# %% [markdown]
# fillna()

# %%
# New_data['name'] = New_data['name'].fillna('--------')

# %%
# dropduplicated()

# %%
titanic
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...               ...     ...                                           ...
# 1305                0       3                            Spector, Mr. Woolf
# 1306                1       1                  Oliva y Ocana, Dona. Fermina
# 1307                0       3                  Saether, Mr. Simon Sivertsen
# 1308                0       3                           Ware, Mr. Frederick
# 1309                0       3                      Peter, Master. Michael J
#
# ...

# %%
# Display the names of all passengers who paid a fare greater than $100 and were under the age of 30.
((titanic['Fare']>100) & (titanic['Age']<30)).value_counts()
# Out:
# False    411
# True       7
# Name: count, dtype: int64

# %% [markdown]
# Study - GroupBy
